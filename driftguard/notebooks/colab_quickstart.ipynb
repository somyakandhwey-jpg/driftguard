# %% [markdown]
# # DriftGuard: Colab Quickstart
#
# Runs Phases 1-5 end to end on the free T4 GPU. Works immediately on synthetic data; see `data/download_elliptic.py` to plug in the real Elliptic dataset.

# %%
# !git clone https://github.com/<your-username>/driftguard.git
# %cd driftguard
# !pip install -q -r requirements.txt

# %%
# Phase 1: tabular MLP baseline
# !python training/train_phase1_mlp.py

# %%
# Phase 2: GraphSAGE on the transaction graph
# !python training/train_phase2_gnn.py

# %%
# Phase 3: show a static model degrading under concept drift
# !python training/train_phase3_drift_sim.py

# %%
# Phase 4: continual learning (EWC + replay) vs naive fine-tuning
# !python training/train_phase4_continual.py

# %%
# Phase 5: unsupervised graph diffusion detector, updated continually
# !python training/train_phase5_diffusion.py
